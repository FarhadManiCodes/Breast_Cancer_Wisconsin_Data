# %% [markdown]
# # Geting the data

# %% [markdown]
# ## load the data

# %%
import os
import pandas as pd
import numpy as np 
from IPython.display import display as disp
# The following is to make some plots along the way 
import seaborn as sns 
import matplotlib.pyplot as plt

DATA_PATH = "datasets"

def load_data(data_path:str =DATA_PATH) -> pd.DataFrame:
    """read the data from csv and return panda data from,"""
    csv_path = os.path.join(data_path,"data.csv")
    return pd.read_csv(csv_path,index_col=0)

# %%
df_cancer = load_data()
df_cancer.head()
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  radius_worst  \
# id                                            ...
# ...

# %%
df_cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 569 entries, 842302 to 92751
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %% [markdown]
# ## Check on particular parameters

# %%
diagnosis= df_cancer["diagnosis"].value_counts()
disp(diagnosis)
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
df_cancer["diagnosis"] = df_cancer["diagnosis"].map({'B':0,'M':1})

# %% [markdown]
# # Check other parameters:

# %%
df_cancer.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  569.000000   569.000000    569.000000      569.000000   569.000000
# mean     0.372583    14.127292     19.289649       91.969033   654.889104
# std      0.483918     3.524049      4.301036       24.298981   351.914129
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.700000     16.170000       75.170000   420.300000
# 50%      0.000000    13.370000     18.840000       86.240000   551.100000
# 75%      1.000000    15.780000     21.800000      104.100000   782.700000
# max      1.000000    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# # Histogram

# %%
df_cancer.hist(bins=50, figsize=(22,15))
plt.show()

# %% [markdown]
# ## Create a Test Set

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(df_cancer, test_size=0.2, random_state=42)

# %%
diagnosis= train_set["diagnosis"].value_counts()
disp(diagnosis)
# Out:
# 0    286
# 1    169
# Name: diagnosis, dtype: int64

# %%
diagnosis= test_set["diagnosis"].value_counts()
disp(diagnosis)
# Out:
# 0    71
# 1    43
# Name: diagnosis, dtype: int64

# %%
train_set.hist(bins=50, figsize=(22,15))
plt.show()

# %% [markdown]
# # save train and test data

# %%
def save_train_test_data(data_path:str =DATA_PATH) -> None:
    """save the test and train data in csv"""
    test_path = os.path.join(data_path,"test.csv")
    train_path = os.path.join(data_path,"train.csv")
    test_set.to_csv(test_path,index=False)
    train_set.to_csv(train_path,index=False)

save_train_test_data()
